# %%
print("Manoj")
# Out:
# Manoj

# %%
from IPython.core.debugger import bdb
#Day 1
a="Hello"
print(a)
print(id(a))

b="Hello"
print(b)
print(id(b))
# Out:
# Hello
# 138805812909696
# Hello
# 138805812909696

# %%
name = "Manoj kumar"
print(name)
print(id(name))
print(type(name))
# Out:
# Manoj kumar
# 138805810435952
# <class 'str'>

# %%
num = 26.4
print(num)
print(id(num))
print(type(num))

ispresent = True
print(ispresent)
print(id(ispresent))
print(type(ispresent))
# Out:
# 26.4
# 138805815532944
# <class 'float'>
# True
# 10549600
# <class 'bool'>

# %%
roll_no = input("Enter your roll number: ")
print(roll_no)
print(id(roll_no))
print(type(roll_no))
# Out:
# Enter your roll number: 23EACAD073
# 23EACAD073
# 138805811735536
# <class 'str'>

# %%
roll_no = int(input("Enter your roll number: "))
print(roll_no)
print(id(roll_no))
print(type(roll_no))
# Out:
# Enter your roll number: 23
# 23
# 11646056
# <class 'int'>

# %%
roll_no = float(input("Enter your roll number: "))
print(roll_no)
print(id(roll_no))
print(type(roll_no))
# Out:
# Enter your roll number: 23.5
# 23.5
# 138805812023088
# <class 'float'>
