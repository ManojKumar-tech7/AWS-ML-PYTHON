# %% [markdown]
# <a href="https://colab.research.google.com/github/ManojKumar-tech7/AWS-ML-PYTHON/blob/main/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Day 3")
# Out:
# Day 3
